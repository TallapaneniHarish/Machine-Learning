# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('homeprice.csv')
data.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      6 non-null      int64
#  1   bedrooms  5 non-null      float64
#  2   age       6 non-null      int64
#  3   price     6 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 324.0 bytes

# %%
data1 = data.fillna(data['bedrooms'].mean())
data1
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.2   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      6 non-null      int64
#  1   bedrooms  6 non-null      float64
#  2   age       6 non-null      int64
#  3   price     6 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 324.0 bytes

# %%
data1.shape
# Out:
# (6, 4)

# %%
x = data1.drop(['price'], axis= 'columns')
y = data1.price

# %%
print(x)
print(y)
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.2   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
X_train, X_test, y_train, y_test =  train_test_split(x, y, test_size=0.1)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train_prediction = model.predict(X_train)

# %%
from sklearn import metrics

# %%
error_sc0re = metrics.r2_score(y_train, X_train_prediction)
error_sc0re
# Out:
# 0.9543026098066568

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_train, X_train_prediction)
plt.show()

# %%
import numpy as np

input_dsta = (3600, 2.0, 25)
input_data_array = np.asarray(input_dsta)

# reshape into (1, 3) since you have 3 values
input_dsta_reshape = np.reshape(input_data_array, (1, 3))

# now you can use it with model.predict
new_value = model.predict(input_dsta_reshape)
prediction_amount = round(new_value[0], 2)
prediction_amount
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 587803.15

# %%
import pickle

# %%
filesname = 'house.pkl'
pickle.dump(model,open(filesname, 'wb'))

# %%
load_models = pickle.load(open(filesname,'rb'))

# %%
import numpy as np

input_dsta = (3600, 2.0, 25)
input_data_array = np.asarray(input_dsta)

# reshape into (1, 3) since you have 3 values
input_dsta_reshape = np.reshape(input_data_array, (1, 3))

# now you can use it with model.predict
new_value = load_models.predict(input_dsta_reshape)
prediction_amount = round(new_value[0], 2)
prediction_amount
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 587803.15
