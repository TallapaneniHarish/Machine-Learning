# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
data = load_breast_cancer()
dir(data)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
data_df = pd.DataFrame(breast_cancer_data.data, columns = breast_cancer_data.feature_names)
data_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data_df['target'] = breast_cancer_data.target
data_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# 1-Benign
# 2-Malignant

# %%
data_df['target'].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
x = data_df.drop(['target'], axis = 'columns')
y = data_df.target

# %%
print(x)
print(y)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
X = np.asarray(x)
Y = np.asarray(y)

# %%
from sklearn.svm import SVC
model = SVC()

# %%
perametres = {
              'kernel' :['linear', 'poly','rbf', 'sigmoid'],
               'C' :[1, 5, 10, 20]
}

# %%
classifier = GridSearchCV(model, perametres, cv=5)

# %%
classifier.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([3.63472733e+00, 9.02767181e-03, 7.85446167e-03, 2.49197006e-02,
#         7.91291623e+00, 7.70826340e-03, 1.31498814e-02, 2.07838058e-02,
#         9.77573261e+00, 8.14213753e-03, 8.97908211e-03, 2.13476181e-02,
#         1.68111891e+01, 1.19215965e-02, 7.76424408e-03, 2.81299114e-02]),
#  'std_fit_time': array([1.45382598e+00, 2.61272689e-03, 3.58265718e-03, 2.65659826e-03,
#         3.02927433e+00, 2.94439219e-03, 2.89934422e-03, 2.73171171e-03,
#         2.21320421e+00, 1.73460190e-03, 3.67003430e-03, 3.18337657e-03,
#         4.93163907e+00, 3.92023084e-03, 1.95237528e-03, 5.52029889e-03]),
#  'mean_score_time': array([0.00083799, 0.00340047, 0.00910621, 0.00663118, 0.0042953 ,
#         0.00231943, 0.0032753 , 0.00674238, 0.00363388, 0.00498052,
#         0.00664988, 0.00707774, 0.00416727, 0.00297785, 0.00930882,
#         0.0045145 ]),
#  'std_score_time': array([0.0010275 , 0.00363855, 0.00503   , 0.00042696, 0.00230724,
# ...

# %%
best_perametres = classifier.best_params_
best_perametres
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
highest_accuracy = classifier.best_score_
highest_accuracy
# Out:
# 0.9525694767893185

# %%
result = pd.DataFrame(classifier.cv_results_)
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       3.634727      1.453826         0.000838        0.001027        1
# 1       0.009028      0.002613         0.003400        0.003639        1
# 2       0.007854      0.003583         0.009106        0.005030        1
# 3       0.024920      0.002657         0.006631        0.000427        1
# 4       7.912916      3.029274         0.004295        0.002307        5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
grid_search_result = result[['param_C', 'param_kernel', 'mean_test_score']]
print(grid_search_result)
# Out:
#     param_C param_kernel  mean_test_score
# 0         1       linear         0.945536
# 1         1         poly         0.908663
# 2         1          rbf         0.912172
# 3         1      sigmoid         0.460441
# 4         5       linear         0.950815
# 5         5         poly         0.922729
# 6         5          rbf         0.931501
# 7         5      sigmoid         0.411178
# 8        10       linear         0.952569
# 9        10         poly         0.920975
# 10       10          rbf         0.922714
# 11       10      sigmoid         0.402391
# 12       20       linear         0.949061
# 13       20         poly         0.919221
# 14       20          rbf         0.920944
# 15       20      sigmoid         0.398867

# %%
Highest test Score = 95%
Best Perametrs = {'C': 10, 'kernel': 'linear'}

# %% [markdown]
# Randomized Search CV

# %%
model = SVC()

# %%
perametres = {
              'kernel' :['linear', 'poly','rbf', 'sigmoid'],
               'C' :[1, 5, 10, 20]
}

# %%
classfier = RandomizedSearchCV(model, perametres, cv=5)

# %%
classfier.fit(X, Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classfier.cv_results_
# Out:
# {'mean_fit_time': array([5.32360077e-03, 1.62598374e+01, 2.38699913e-02, 1.01482868e-02,
#         2.54968166e-02, 2.25366116e-02, 9.53345408e+00, 1.26210213e-02,
#         1.93228245e-02, 2.21208096e-02]),
#  'std_fit_time': array([1.75256639e-03, 4.92559720e+00, 2.45018362e-03, 2.84907030e-03,
#         3.62948544e-03, 3.52279131e-03, 1.91637807e+00, 4.73951381e-03,
#         1.37612368e-03, 4.00726922e-03]),
#  'mean_score_time': array([0.00351586, 0.0018733 , 0.00512085, 0.00376296, 0.00493279,
#         0.00741296, 0.00502481, 0.00482984, 0.00688214, 0.00575414]),
#  'std_score_time': array([0.0008885 , 0.0020575 , 0.00358728, 0.00333836, 0.00355504,
#         0.0023543 , 0.00186368, 0.00446492, 0.00353708, 0.00275978]),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'sigmoid', 'poly', 'sigmoid', 'poly',
#                     'linear', 'rbf', 'sigmoid', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
# ...

# %%
classfier.best_params_
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
classfier.best_score_
# Out:
# 0.9525694767893185

# %%
resultRCV = pd.DataFrame(classfier.cv_results_)
resultRCV
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.005324      0.001753         0.003516        0.000888          rbf
# 1      16.259837      4.925597         0.001873        0.002058       linear
# 2       0.023870      0.002450         0.005121        0.003587      sigmoid
# 3       0.010148      0.002849         0.003763        0.003338         poly
# 4       0.025497      0.003629         0.004933        0.003555      sigmoid
# 5       0.022537      0.003523         0.007413        0.002354         poly
# 6       9.533454      1.916378         0.005025        0.001864       linear
# 7       0.012621      0.004740         0.004830        0.004465          rbf
# 8       0.019323      0.001376         0.006882        0.003537      sigmoid
# 9       0.022121      0.004007         0.005754        0.002760      sigmoid
#
#    param_C                          params  split0_test_score  \
# ...

# %%
Randomized_search_result = resultRCV[['param_C','params','mean_test_score']]
Randomized_search_result
# Out:
#    param_C                          params  mean_test_score
# 0       20      {'kernel': 'rbf', 'C': 20}         0.920944
# 1       20   {'kernel': 'linear', 'C': 20}         0.949061
# 2        5   {'kernel': 'sigmoid', 'C': 5}         0.411178
# 3       10     {'kernel': 'poly', 'C': 10}         0.920975
# 4        1   {'kernel': 'sigmoid', 'C': 1}         0.460441
# 5       20     {'kernel': 'poly', 'C': 20}         0.919221
# 6       10   {'kernel': 'linear', 'C': 10}         0.952569
# 7        5       {'kernel': 'rbf', 'C': 5}         0.931501
# 8       20  {'kernel': 'sigmoid', 'C': 20}         0.398867
# 9       10  {'kernel': 'sigmoid', 'C': 10}         0.402391

# %% [markdown]
# Highest score =95.2
# Best perametres  = {'kernel': 'linear', 'C': 10}
